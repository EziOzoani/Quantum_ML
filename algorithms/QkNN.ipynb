# %%
import qiskit as q
# %matplotlib inline
from qiskit import *

# %%
from qiskit import IBMQ
IBMQ.save_account('0c873d31eb087142dd11b0c107bf3a1cb59f6b5752185b6c9534a79888ced204ceac34df40070fb24f56d55353cb25d67256e770066744ddf839c6e388e69639')
# Out:
# configrc.store_credentials:WARNING:2021-01-15 00:42:32,748: Credentials already present. Set overwrite=True to overwrite.

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

# %%
#USE HAMMING DISTANCE

# %%
#Hamming distance is defined as counting the number of which the corresponding symbols of a two bit vectors of equal length are different e.g

#Hamming Distance:( 0110  0001) has a distance of 2
#Hamming Distance:( 0110  1110) has a distance of 3

# %%
#metric used for measuring similarity. It’s just a traditional XOR

# %%
#Register coutn increased 
qreg_q = QuantumRegister(9, 'q')
creg_c = ClassicalRegister(9, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

# %%
#different illustraitve options
circuit.draw() # will give an ascii representation of the circuit
circuit.draw(output="mpl")

# %%
#STEP 2). Unclassified quantum state in the first register, training set |T⟩ in the second register, ancillary qubit in the last register.

# %%
circuit.h(qreg_q[0]) #The H, or Hadamard, gate rotates the states  and  to  and , respectively.
circuit.h(qreg_q[1])#It is useful for making superpositions. If you have a universal gate set on a classical computer and add the Hadamard gate, 
#it becomes a universal gate set on a quantum computer.

# %%
#ancillary qubit in the last register. --> make use of the identity gate which is actually the absence of a gate. 
#It ensures that nothing is applied to a qubit for one unit of gate time.

# %%
circuit.id(qreg_q[4])
circuit.id(qreg_q[5])
circuit.id(qreg_q[6])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])
circuit.draw(output="mpl")

# %%
#STEP 3). Apply a CNOT --> the result of q2,q3, minus each of the elements of the superposition

# %%
circuit.x(qreg_q[3])#The NOT gate, also known as the Pauli X gate, flips the  state to , and vice versa. 
circuit.cx(qreg_q[1], qreg_q[3])#CNOT gate (ontrolled NOT)
# acts on a pair of qubits, with one acting as ‘control’ and the other as ‘target’. It performs a NOT on the target whenever the control is in state |1>
# If the control qubit is in a superposition, this gate creates entanglement.
circuit.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├─────
#      ├───┤
# q_1: ┤ H ├──■──
#      └───┘  │
# q_2: ───────┼──
#      ┌───┐┌─┴─┐
# q_3: ┤ X ├┤ X ├
#      ├───┤└───┘
# q_4: ┤ I ├─────
#      ├───┤
# q_5: ┤ I ├─────
#      ├───┤
# q_6: ┤ I ├─────
#      ├───┤
# q_7: ┤ I ├─────
#      ├───┤
# q_8: ┤ I ├─────
#      └───┘
# c: 9/══════════

# %%
circuit.id(qreg_q[4])
circuit.cx(qreg_q[0], qreg_q[2])
circuit.id(qreg_q[5])
circuit.id(qreg_q[6])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])
circuit.draw(output="mpl")

# %%
circuit.id(qreg_q[3])
circuit.id(qreg_q[4])
circuit.id(qreg_q[5])
circuit.id(qreg_q[6])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])
circuit.draw(output="mpl")

# %%
circuit.id(qreg_q[0])
circuit.id(qreg_q[1])

circuit.x(qreg_q[2])
circuit.x(qreg_q[3])
circuit.x(qreg_q[4])

circuit.id(qreg_q[5])

circuit.x(qreg_q[6])

circuit.id(qreg_q[7])
circuit.id(qreg_q[8])

circuit.barrier()

circuit.draw(output="mpl")

# %%
circuit.ccx(qreg_q[2], qreg_q[5], qreg_q[4])

circuit.id(qreg_q[6])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])

circuit.draw(output="mpl")

# %%
circuit.ccx(qreg_q[2], qreg_q[5], qreg_q[6])

circuit.id(qreg_q[7])
circuit.id(qreg_q[8])

circuit.draw(output="mpl")

# %%
circuit.ccx(qreg_q[2], qreg_q[6], qreg_q[5])


circuit.id(qreg_q[7])
circuit.id(qreg_q[8])

circuit.draw(output="mpl")

# %%
circuit.x(qreg_q[6])
          
#circuit.id(qreg_q[2])



circuit.id(qreg_q[5])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])

circuit.draw(output="mpl")

# %%
""""
aPlusb = QuantumCircuit(7,name='aPlusb')
aPlusb.ccx(3,5,4)
aPlusb.ccx(3, 5, 6)
aPlusb.ccx(3, 6, 5)
aPlusb.x(6)
aPlusb.to_gate()
"""
# Out:
# '"\naPlusb = QuantumCircuit(7,name=\'aPlusb\')\naPlusb.ccx(3,5,4)\naPlusb.ccx(3, 5, 6)\naPlusb.ccx(3, 6, 5)\naPlusb.x(6)\naPlusb.to_gate()\n'

# %%
#aPlusb.draw()
#circuit.append(aPlusb[])
#circuit.draw(output="mpl")

# %%
#aPlusb.draw(output="mpl")

# %%
#n = 8
#OR = QuantumCircuit(n,name='OR')
"""
OR.x(3)
OR.x(4)
OR.x(5)

OR.ccx(3, 4, 6)
OR.ccx(5, 6, 7)

OR.x(7)
OR.to_gate()
"""
# Out:
# '\nOR.x(3)\nOR.x(4)\nOR.x(5)\n\nOR.ccx(3, 4, 6)\nOR.ccx(5, 6, 7)\n\nOR.x(7)\nOR.to_gate()\n'

# %%
#OR.draw(output="mpl")

# %%
#circuit.append(OR,[1,2,3,4,5,6,7,8])
#circuit = QuantumCircuit(qreg_q, creg_c, OR)
circuit.barrier()
circuit.draw(output="mpl")

# %%
circuit.ccx(qreg_q[3], qreg_q[5], qreg_q[4])



circuit.id(qreg_q[6])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])
circuit.draw(output="mpl")

# %%
circuit.ccx(qreg_q[3], qreg_q[5], qreg_q[6])

circuit.id(qreg_q[7])
circuit.id(qreg_q[8])

circuit.draw(output="mpl")

# %%
circuit.ccx(qreg_q[3], qreg_q[6], qreg_q[5])

circuit.id(qreg_q[7])
circuit.id(qreg_q[8])
circuit.draw(output="mpl")

# %%
circuit.x(qreg_q[6])


#circuit.id(qreg_q[3])
#circuit.id(qreg_q[4])


#circuit.id(qreg_q[5])
circuit.id(qreg_q[7])
circuit.id(qreg_q[8])
circuit.draw(output="mpl")

# %%
circuit.barrier()
circuit.x(qreg_q[4])
circuit.x(qreg_q[5])
circuit.x(qreg_q[6])

circuit.draw(output="mpl")

# %%
#circuit.x(qreg_q[3])
#circuit.x(qreg_q[4])
#circuit.x(qreg_q[5])

circuit.ccx(qreg_q[4], qreg_q[5], qreg_q[7])
circuit.ccx(qreg_q[6], qreg_q[7], qreg_q[8])

circuit.x(qreg_q[8])
circuit.draw(output="mpl")

# %%
#measure

# %%
circuit.barrier()

# %%
circuit.measure([0,1,2,3,4,5,6,7,8], [0,1,2,3,4,5,6,7,8])
circuit.draw(output="mpl")

# %%
#testing -->simulator

# %%
from qiskit.visualization import plot_histogram

# %%
Aer.backends() # finds current simulators
# Out:
# [QasmSimulator(
#  backend_name='qasm_simulator', provider=AerProvider()),
#  StatevectorSimulator(
#  backend_name='statevector_simulator', provider=AerProvider()),
#  UnitarySimulator(
#  backend_name='unitary_simulator', provider=AerProvider()),
#  PulseSimulator(
#  backend_name='pulse_simulator', provider=AerProvider())]

# %%
emulator = Aer.get_backend('qasm_simulator')

job = execute( circuit, emulator, shots=8192 )

# %%
hist = job.result().get_counts()
plot_histogram(hist)

# %%
#testing -->Quantum machine

# %%
IBMQ.delete_account()

# %%
IBMQ.active_account()

# %%
IBMQ.save_account('b35ee002c40b58f68333b4dc663e57f118764a66394591bc1270dd258ede51076296505fe28203f55935798b133fda9814350ca6b975b3899b38cbda9a034725', overwrite=True)

# %%
IBMQ.load_account()
provider= IBMQ.get_provider(hub='ibm-q')
real_device = provider.get_backend('ibmq_16_melbourne')
# Out:
# /Users/ezi/opt/anaconda3/lib/python3.7/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
properties = real_device.properties()
coupling_map = real_device.configuration().coupling_map

# %%
#Some playign around to reduce noise and to ensure more consistent runs
#
from qiskit.providers.aer.noise import NoiseModel

noise_model = NoiseModel.from_backend(properties)

# %%
"""
job = execute(circuit, emulator, shots=1050, noise_model=noise_model,
                    coupling_map=coupling_map,
                    basis_gates=noise_model.basis_gates)
print(job.job_id())
from qiskit.tools.monitor import job_monitor
job_monitor(job)

"""
job = execute(circuit, backend = real_device, shots=1024)
print(job.job_id())
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# 6000e5209e0e7fcd5eb3069e
# Job Status: job has successfully run

# %%
device_result = job.result()
plot_histogram(device_result.get_counts(circuit))

# %%
#STEP 4) Compute Hamming distance {TBD}

# %%
#Notes --> rough work

# %%
#Once the addition is done, select the most significant qubit and use the quantum OR gate to get the signal COND^p,
#which indicates the condition of Hamming distance <=t

# %%
#We want to select the ones that have a hamming distance lower than a certain t  [we have them in superposition]

# %%
#So for 00001, the two lowest  ‘01’ encode one the elements of the training set. 
#The following two ( reading from right to left), encode the result of subtracting the input e,g ‘10’, against that element of the training set

# %%
#Now the filter will say that we want only the ones below a certain threshold in terms of their hamming distance.
#Proposed way to do this is to add a constant , some a, so if they overflow then the hamming distance is there.
